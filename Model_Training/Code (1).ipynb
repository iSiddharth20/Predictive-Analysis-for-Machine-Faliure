# %% [markdown]
# # Importing Libraries

# %%
# Basic File handling
import pandas as pd
import numpy as np

# Data Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# Pre-Processing while Training
import sklearn
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

# Splitting data for Model Training
from sklearn.model_selection import train_test_split 

# Training Model
from sklearn.ensemble import RandomForestClassifier
# Random Forest Classifier was chosen because it was most Accurate

# Model Evaluation : Accuracy Score
from sklearn.metrics import accuracy_score

# Export Trained Model as *.pkl
from sklearn.externals import joblib


# Run This Cell 'Twice' to Remove All Errors
# Out:
# c:\python3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
import scipy

scipy.__version__
# Out:
# '1.4.1'

# %% [markdown]
# # Data Pre-Processing

# %%
# Getting the Data Set in the Program
data=pd.read_csv('https://raw.githubusercontent.com/iSiddharth20/Predictive-Analysis-for-Machine-Faliure/master/dataset.csv')

# %% [markdown]
# #### Identifing and Removing Null Values from : Pressure , Moisture , Temperature , Broken

# %%
# Identifing Null Values from "Pressure"
data[data['pressureInd'].isnull()]
# Out:
#        Random  Machine_nbr  lifetime  pressureInd  moistureInd  \
# 29   0.208998          350        41          NaN    81.576619
# 67   0.807607          396        72          NaN   102.418595
# 450  0.552764          289        61          NaN          NaN
# 489  0.408711          945        66          NaN          NaN
# 622  0.231253          983        63          NaN    98.237506
#
#      temperatureInd  team  provider broken
# 29       127.597829     3         2     No
# 67        97.143731     2         2     No
# 450       85.154566     3         1     No
# 489      135.169317     2         1    Yes
# 622             NaN     2         3    Yes

# %%
# Identifing Null Values from "Moisture"
data[data['moistureInd'].isnull()]
# Out:
#        Random  Machine_nbr  lifetime  pressureInd  moistureInd  \
# 19   0.793356          907        65    86.499784          NaN
# 243  0.569958           71        46    87.636028          NaN
# 450  0.552764          289        61          NaN          NaN
# 489  0.408711          945        66          NaN          NaN
#
#      temperatureInd  team  provider broken
# 19        92.645987     2         3    Yes
# 243      114.600177     2         4     No
# 450       85.154566     3         1     No
# 489      135.169317     2         1    Yes

# %%
# Identifing Null Values from "Temperature"
data[data['temperatureInd'].isnull()]
# Out:
#        Random  Machine_nbr  lifetime  pressureInd  moistureInd  \
# 49   0.333839           73        93    87.738554   100.043591
# 92   0.476000           17        80    92.483469    92.383153
# 622  0.231253          983        63          NaN    98.237506
#
#      temperatureInd  team  provider broken
# 49              NaN     1         3     No
# 92              NaN     2         1    Yes
# 622             NaN     2         3    Yes

# %%
# Identifing Null Values from "Broken"
data[data['broken'].isnull()]
# Out:
#        Random  Machine_nbr  lifetime  pressureInd  moistureInd  \
# 9    0.923187          140        79    87.421990   110.941574
# 181  0.609019          927        92   116.740412   104.204599
# 536  0.747285          315        12    69.807790    83.670698
# 659  0.787838           36        80   111.991442   106.257524
#
#      temperatureInd  team  provider broken
# 9        129.691510     2         1    NaN
# 181      129.384729     1         2    NaN
# 536       82.236458     1         2    NaN
# 659      110.334142     2         1    NaN

# %%
# Removing all the Null Values
data.dropna(inplace=True)

# %%
# First 5 Rows of the Data
data.head()
# Out:
#      Random  Machine_nbr  lifetime  pressureInd  moistureInd  temperatureInd  \
# 0  0.437420          723        60    77.836105   112.832544      121.786371
# 1  0.688345          107        88    89.350620    95.228125       99.082317
# 2  0.805670          153        30   130.089477    96.367747      103.608344
# 3  0.923187          140        79    87.421990   110.941574      129.691510
# 4  0.036583          359         2    69.939898    86.292387       91.861983
#
#    team  provider broken
# 0     3         3    Yes
# 1     1         4    Yes
# 2     1         3     No
# 3     2         1    Yes
# 4     3         3     No

# %% [markdown]
# ***
# Observations :
# Filling the Null Values with Mean reduced the Accuracy. Hence, those entries were Dropped.
# ***

# %% [markdown]
# # Data Visualization

# %% [markdown]
# #### Visualizing Distribution of Data Key Factors : Pressure , Moisture , Temperature

# %%
# Distribution Plot of "Pressure"
sns.distplot(data['pressureInd'])

# %%
# Distribution Plot of "Moisture"
sns.distplot(data['moistureInd'])

# %%
# Distribution Plot of "Temperature"
sns.distplot(data['temperatureInd'])

# %% [markdown]
# ***
# Observation :
# The Data appears to be Normally Distributed which means predictions will be precise
# ***

# %% [markdown]
# #### Observing "Yes" vs "No" ratio in Target variable : "Broken"

# %%
sns.countplot(data=data,x=data['broken'])

# %% [markdown]
# # Identifying Outliers

# %%
sns.boxplot(x = data['pressureInd'])

# %%
sns.boxplot(x = data['temperatureInd'])

# %%
sns.boxplot(x = data['moistureInd'])

# %%
Q1 = data.quantile(0.25) #Removing Outliers using InterQuartile Range
Q3 = data.quantile(0.75) 
IQR = Q3 - Q1
print(IQR)
# Out:
# Random              0.500838
# Machine_nbr       499.500000
# lifetime           46.000000
# pressureInd        26.695114
# moistureInd        13.348999
# temperatureInd     25.985972
# team                2.000000
# provider            2.000000
# dtype: float64

# %%
data = data[~((data < (Q1 - 1.5 * IQR)) |(data > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
# After removing Outliers

sns.boxplot(x = data['moistureInd'])

# %% [markdown]
# ***
# Observation : There appear to be more 'No' values than 'Yes' Values
# ***

# %% [markdown]
# #### Analyzing Dependency of Factors over our Target Variable : State of Machine : "Broken" Using Scatter Plot

# %%
# Pressure and Lifetime
plt.figure(figsize=(10,4))
sns.scatterplot(data=data,x=data['lifetime'],y=data['pressureInd'],hue=data['broken'])

# %%
# Moisture and Lifetime
plt.figure(figsize=(10,4))
sns.scatterplot(data=data,x=data['lifetime'],y=data['moistureInd'],hue=data['broken'])

# %%
# Temperature and Lifetime
plt.figure(figsize=(10,4))
sns.scatterplot(data=data,x=data['lifetime'],y=data['temperatureInd'],hue=data['broken'])

# %% [markdown]
# # Machine Learning Model

# %%
# Check for Null Values

data.isnull().sum()
# Out:
# Random            0
# Machine_nbr       0
# lifetime          0
# pressureInd       0
# moistureInd       0
# temperatureInd    0
# team              0
# provider          0
# broken            0
# dtype: int64

# %% [markdown]
# ***
# Observation : There are No Null Values
# ***

# %%
# Encoding Values to Unique Integers to aid Mathematical Calculations

data['broken']= label_encoder.fit_transform(data['broken']) 

data['broken'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
'''
X : Features and Dependent Variables
y : Target Variable
'''

X = data.drop('broken',axis = 1)
y = data['broken']

# %%
# Splitting the Data for Training and Testing in 70:30 Ratio

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3,random_state = 0)

# %% [markdown]
# ***
# Observation : Data is Verified, Encoded, Split
# ***

# %% [markdown]
# #### Fitting and Training the Model

# %%
model = RandomForestClassifier(max_depth=10, random_state=0)
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=10, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %% [markdown]
# #### Testing the Model

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# #### Checking Accuracy

# %%
y_pred = model.predict(X_test)
print("accuracy score: ",accuracy_score(y_test,y_pred)*100)
# Out:
# accuracy score:  94.21768707482994

# %% [markdown]
# ***
# Observation : Accuracy is always more than 92%
# ***

# %% [markdown]
# # Exporting the Trained Model

# %%
joblib.dump(model,"classification_model.pkl")
# Out:
# ['classification_model.pkl']

# %%
import flask
flask.__version__
# Out:
# '1.1.2'

# %%
np.version.version
# Out:
# '1.18.1'
